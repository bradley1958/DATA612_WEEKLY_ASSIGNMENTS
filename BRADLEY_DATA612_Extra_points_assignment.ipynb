# %% [markdown]
# # Extra points

# %% [markdown]
# ## Challenge
#
# Go to 'https://www.gapminder.org/data/'. Click on 'Select an Indicator' arrow then select 'Health'
# then 'Vaccine' to finally select 'DTP3 immunizet' page.
#
#   - Load the data shown on the HTML page using pd.read_html() method.
#   - If able to load the data, write a jupyter notebook or python script and contribute your solution to the GitHub community.

# %% [markdown]
# ## Example
# Below is an example of how to use .read_html 'pandas' method to load html data.

# %%
import pandas as pd
# Import the required dataset from the website
df = pd.read_csv('dtp3_immunized_percent_of_one_year_olds.csv')

# %%
# Let's see the first 5 rows
df.head(188)
# Out:
#             country  1980  1981  1982  1983  ...  2007  2008  2009  2010  2011
# 0       Afghanistan  0.04  0.03  0.05  0.05  ...  0.63  0.64  0.63  0.66  0.66
# 1           Albania  0.94  0.94  0.95  0.95  ...  0.98  0.99  0.98  0.99  0.99
# 2           Algeria   NaN   NaN   NaN   NaN  ...  0.95  0.93  0.95  0.95  0.95
# 3           Andorra   NaN   NaN   NaN   NaN  ...  0.96  0.99  0.99  0.99  0.99
# 4            Angola   NaN   NaN   NaN  0.06  ...  0.83  0.81  0.73  0.91  0.86
# ..              ...   ...   ...   ...   ...  ...   ...   ...   ...   ...   ...
# 183  United Kingdom  0.41  0.46  0.53  0.59  ...  0.92  0.92  0.93  0.94  0.95
# 184   United States  0.96  0.96  0.96  0.97  ...  0.95  0.95  0.94  0.94  0.94
# 185         Uruguay  0.53  0.57  0.67  0.73  ...  0.94  0.94  0.95  0.95  0.95
# 186      Uzbekistan   NaN   NaN   NaN   NaN  ...  0.96  0.98  0.98  0.99  0.99
# 187         Vanuatu   NaN   NaN  0.22  0.27  ...  0.68  0.68  0.68  0.68  0.68
#
# [188 rows x 33 columns]

# %%
# Let's get some general info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 33 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   country  193 non-null    object
#  1   1980     102 non-null    float64
#  2   1981     122 non-null    float64
#  3   1982     127 non-null    float64
#  4   1983     140 non-null    float64
#  5   1984     149 non-null    float64
#  6   1985     155 non-null    float64
#  7   1986     158 non-null    float64
#  8   1987     160 non-null    float64
#  9   1988     162 non-null    float64
#  10  1989     162 non-null    float64
#  11  1990     162 non-null    float64
#  12  1991     163 non-null    float64
#  13  1992     181 non-null    float64
#  14  1993     186 non-null    float64
#  15  1994     187 non-null    float64
#  16  1995     187 non-null    float64
#  17  1996     187 non-null    float64
#  18  1997     188 non-null    float64
#  19  1998     187 non-null    float64
# ...

# %%
# Let's load some more pandas features
import sys
import numpy as np
# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt
import pandas.util.testing as tm
from pandas import set_option
import plotly.express as px
from plotly.offline import  download_plotlyjs, init_notebook_mode, plot, iplot
import cufflinks as cf
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# Let's see the Column Headings
print(df.columns)
# Out:
# Index(['country', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011'],
#       dtype='object')

# %%
# let's just look at the UK and the US
df.iloc[183:185]
# Out:
#             country  1980  1981  1982  1983  ...  2007  2008  2009  2010  2011
# 183  United Kingdom  0.41  0.46  0.53  0.59  ...  0.92  0.92  0.93  0.94  0.95
# 184   United States  0.96  0.96  0.96  0.97  ...  0.95  0.95  0.94  0.94  0.94
#
# [2 rows x 33 columns]

# %%
# Let's look at a Bar Chart of the UK vs. US for 1980, 1981, and 1982
data = {"United Kingdom":[0.41, 0.46, 0.53], "United States":[0.96, 0.96, 0.96]}
index = ["1980", "1981", "1982"];
dataFrame = pd.DataFrame(data=data, index=index);
dataFrame.plot.bar(rot=15, title="UK vs. US DTP3 Immunizations 1980 to 1982");
plot.show(block=True);
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-41-eaa2e3ff8076> in <module>()
#       4 dataFrame = pd.DataFrame(data=data, index=index);
#       5 dataFrame.plot.bar(rot=15, title="UK vs. US DTP3 Immunizations 1980 to 1982");
# ----> 6 plot.show(block=True);
#
# AttributeError: 'function' object has no attribute 'show'
